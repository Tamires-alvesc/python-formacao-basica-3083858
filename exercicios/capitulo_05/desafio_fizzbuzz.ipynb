# %% [markdown]
# - Crie um objeto iterável com 100 dados do tipo numérico e imprima na tela a palavra 'Fizz' no lugar dos números divisíveis por 3, 'Buzz' no lugar dos números divisíveis por 05 e 'FizBuzz' no lugar dos números divisíveis por 3 e 5. Caso o número não atenda a nenhuma dessas condições, imprima o próprio número.

# %%
from random import randint

lista100 = []

for c in range(0,100):
    n = randint(0,300)
    lista100.append(n)
print(lista100)

for i in range(len(lista100)):
    if (lista100[i] % 3 == 0) and (lista100[i] % 5 == 0):
        lista100[i] = "FizzBuzz"
    elif lista100[i] % 3 == 0:
        lista100[i] = "Fizz"
    elif lista100[i] % 5 == 0:
        lista100[i] = "Buzz"

print(lista100)
# Out:
# [257, 81, 62, 270, 21, 178, 100, 92, 170, 225, 259, 185, 265, 114, 183, 88, 200, 64, 249, 1, 21, 260, 140, 27, 300, 152, 160, 42, 46, 183, 256, 14, 225, 288, 253, 148, 154, 148, 288, 276, 87, 192, 78, 96, 21, 137, 30, 51, 248, 55, 63, 247, 278, 121, 194, 282, 147, 127, 159, 156, 225, 59, 97, 273, 181, 244, 132, 149, 203, 116, 107, 75, 271, 175, 261, 50, 110, 115, 91, 75, 102, 242, 87, 33, 90, 13, 190, 132, 8, 203, 123, 84, 81, 280, 168, 146, 0, 269, 87, 169]
# [257, 'Fizz', 62, 'FizzBuzz', 'Fizz', 178, 'Buzz', 92, 'Buzz', 'FizzBuzz', 259, 'Buzz', 'Buzz', 'Fizz', 'Fizz', 88, 'Buzz', 64, 'Fizz', 1, 'Fizz', 'Buzz', 'Buzz', 'Fizz', 'FizzBuzz', 152, 'Buzz', 'Fizz', 46, 'Fizz', 256, 14, 'FizzBuzz', 'Fizz', 253, 148, 154, 148, 'Fizz', 'Fizz', 'Fizz', 'Fizz', 'Fizz', 'Fizz', 'Fizz', 137, 'FizzBuzz', 'Fizz', 248, 'Buzz', 'Fizz', 247, 278, 121, 194, 'Fizz', 'Fizz', 127, 'Fizz', 'Fizz', 'FizzBuzz', 59, 97, 'Fizz', 181, 244, 'Fizz', 149, 203, 116, 107, 'FizzBuzz', 271, 'Buzz', 'Fizz', 'Buzz', 'Buzz', 'Buzz', 91, 'FizzBuzz', 'Fizz', 242, 'Fizz', 'Fizz', 'FizzBuzz', 13, 'Buzz', 'Fizz', 8, 203, 'Fizz', 'Fizz', 'Fizz', 'Buzz', 'Fizz', 146, 'FizzBuzz', 269, 'Fizz', 169]
